# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,spectral_clustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

# %%
#loading the dataset
df = pd.read_csv(r"C:\Users\aadit\OneDrive\Documents\MACHINE LEARNING\End to End ML projects\Market Segmentation in Insurance\Customer Data.csv")

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
#nearly 3.5 % of
# Out:
# CUST_ID                             0.000000
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.011173
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    3.497207
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %%
# checking for duplicate rows in the dataset
df.duplicated().sum()
# Out:
# 0

# %%
df['MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean())

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df=df.drop(columns='CUST_ID',axis=1)

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
plt.figure(figsize=(30,45))
for i, col in enumerate(df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(9,2,i+1)
        sns.kdeplot(df[col],ax=ax)
        plt.xlabel(col)

# %%
plt.figure(figsize=(10,60))
for i in range(0,17):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]],kde_kws={'color':'b','bw':0.1,'lw':3,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(df.columns[i])
plt.tight_layout()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ## scaling the dataframe

# %%
scaled_df = scalar.fit_transform(df)
#scaling the data

# %%
SSE =[]

for cluster in range(1,10):
    kmeans = KMeans(n_clusters = cluster, init='k-means++')
    kmeans.fit(df)
    SSE.append(kmeans.inertia_)

# %%
frame = pd.DataFrame({'Cluster':range(1,10),'SSE':SSE})
frame
# Out:
#    Cluster           SSE
# 0        1  3.930610e+11
# 1        2  2.792966e+11
# 2        3  2.328061e+11
# 3        4  2.067315e+11
# 4        5  1.817582e+11
# 5        6  1.624520e+11
# 6        7  1.451882e+11
# 7        8  1.328727e+11
# 8        9  1.241869e+11

# %%
plt.figure(figsize=(12,6))
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('number of cluster')
plt.ylabel('Inertia')
#ploting the inertia
# Out:
# Text(0, 0.5, 'Inertia')

# %%
#silhouette coefficient
kmeans = KMeans(n_clusters=4,init='k-means++')
kmeans.fit(scaled_df)
print(silhouette_score(scaled_df,kmeans.labels_,metric='euclidean'))
# 19% is a bad score
# Out:
# 0.1976074492720698

# %%
#Principal Component Analysis
# When we run PCA on a data frame, new components are created. These components explain the maximum variance in the model
pca = PCA(n_components=4)
principalComponents = pca.fit_transform(scaled_df)

features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_,color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)

PCA_components = pd.DataFrame(principalComponents)

# %%
ks = range(1,10)
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(PCA_components.iloc[:,:3])
    inertias.append(model.inertia_)
    
plt.plot(ks, inertias,'-o',color='black')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()
#it looks like the optimal number of clusters is 5

# %%
model = KMeans(n_clusters=4)
model.fit(PCA_components.iloc[:,:2])

print(silhouette_score(PCA_components.iloc[:,:2],model.labels_,metric='euclidean'))
#We can calculate the silhouette score for this model with 5 clusters
#we are getting 50% better than previous model
# Out:
# 0.4076684313470494

# %%
#Principal Component Analysis we using n_components=2
# When we run PCA on a data frame, new components are created. These components explain the maximum variance in the model
pcaa = PCA(n_components=2)
principal_components = pcaa.fit_transform(scaled_df)

features = range(pcaa.n_components_)
plt.bar(features, pca.explained_variance_ratio_,color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)

PCA_componentss = pd.DataFrame(principal_components)

# pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
# pca_df

# %%
ks = range(1,10)
inertiass = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(PCA_componentss.iloc[:,:2])
    inertiass.append(model.inertia_)
    
plt.plot(ks, inertias,'-o',color='black')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
model = KMeans(n_clusters=3)
model.fit(PCA_componentss.iloc[:,:2])

print(silhouette_score(PCA_componentss.iloc[:,:2],model.labels_,metric='euclidean'))
# Out:
# 0.4523239911762156

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682218 -1.076443
# 1    -1.138283  2.506511
# 2     0.969659 -0.383618
# 3    -0.873621  0.043186
# 4    -1.599434 -0.688579
# ...        ...       ...
# 8945 -0.359632 -2.016154
# 8946 -0.564374 -1.639140
# 8947 -0.926206 -1.810792
# 8948 -2.336546 -0.657938
# 8949 -0.556429 -0.400489
#
# [8950 rows x 2 columns]

# %%
kmeans_model=KMeans(3)
kmeans_model.fit_predict(scaled_df)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)
pca_df_kmeans
# Out:
#           PCA1      PCA2  cluster
# 0    -1.682218 -1.076443        0
# 1    -1.138283  2.506511        2
# 2     0.969659 -0.383618        0
# 3    -0.873621  0.043186        0
# 4    -1.599434 -0.688579        0
# ...        ...       ...      ...
# 8945 -0.359632 -2.016154        0
# 8946 -0.564374 -1.639140        0
# 8947 -0.926206 -1.810792        0
# 8948 -2.336546 -0.657938        0
# 8949 -0.556429 -0.400489        0
#
# [8950 rows x 3 columns]

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmeans,palette=['red','green','blue'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
# find all cluster centers
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[df.columns])
# inverse transform the data
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[df.columns])
cluster_centers.head()
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0   808.330269          0.834711   496.068247       247.278939
# 1  2182.352833          0.981702  4187.017796      2663.995153
# 2  4021.408443          0.958669   389.029026       252.310839
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             249.110368   338.161935            0.460367
# 1            1523.493231   449.753140            0.948175
# 2             136.797412  3920.524750            0.233845
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.129204                         0.342052
# 1                   0.664780                         0.739630
# 2                   0.111752                         0.145661
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX CREDIT_LIMIT  \
# 0               0.069534         1.235525      8.480209  3266.612371
# 1               0.062415         1.507451     55.692549  7642.784314
# ...

# %%
# Creating a target column "Cluster" for storing the cluster segment
cluster_df = pd.concat([df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1_df = cluster_df[cluster_df['cluster']==0]
cluster_1_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_2_df = cluster_df[cluster_df['cluster']==1]
cluster_2_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      627.260806           1.000000    7091.01           6402.63
# 12    1516.928620           1.000000    3217.99           2500.23
# 21    6369.531318           1.000000    6359.95           5910.04
# 34    3517.101616           0.727273     547.28              0.00
# 37    4047.480828           1.000000    2380.55           1642.17
# ...           ...                ...        ...               ...
# 8689   368.318662           0.909091    8053.95           8053.95
# 8698   873.680279           1.000000    2397.05           1072.46
# 8707    78.448912           1.000000    1875.18            977.85
# 8737  2533.618119           0.909091    5633.83           2985.92
# 8856   227.220411           1.000000    1387.60            288.54
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# ...

# %%
cluster_3_df = cluster_df[cluster_df['cluster']==2]
cluster_3_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    6886.213231           1.000000    1611.70              0.00
# 23    3800.151377           0.818182    4248.35           3454.56
# 24    5368.571219           1.000000       0.00              0.00
# 28    7152.864372           1.000000     387.05            204.55
# ...           ...                ...        ...               ...
# 8858   812.934042           1.000000      50.00             50.00
# 8869  2171.222526           1.000000     791.18            791.18
# 8915   381.341657           1.000000      78.00              0.00
# 8917  1880.817982           1.000000       0.00              0.00
# 8941  5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# ...

# %%
sns.countplot(x='cluster',data=cluster_df)
# Out:
# <AxesSubplot:xlabel='cluster', ylabel='count'>

# %%
for c in cluster_df:
    grid = sns.FacetGrid(cluster_df,col='cluster')
    grid = grid.map(plt.hist,c)
plt.show()

# %% [markdown]
# ## Saving the kmeans clustering model and the data with cluster label

# %%
import joblib
joblib.dump(kmeans_model,'kmeans_seg_model')
# Out:
# ['kmeans_seg_model']

# %%
cluster_df.to_csv('clustered_seg_filecsv.csv')

# %% [markdown]
# ## Training and Testing the model accuracy using decision tree

# %%
X = cluster_df.drop(['cluster'],axis=1)
y = cluster_df[['cluster']]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train.shape
# Out:
# (6265, 17)

# %%
X_test.shape
# Out:
# (2685, 17)

# %%
#decision tree
model = DecisionTreeClassifier(criterion='entropy')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
#confusion_matrix
print(metrics.confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1777   31   36]
#  [  37  313    4]
#  [  34   14  439]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1844
#            1       0.87      0.88      0.88       354
#            2       0.92      0.90      0.91       487
#
#     accuracy                           0.94      2685
#    macro avg       0.92      0.92      0.92      2685
# weighted avg       0.94      0.94      0.94      2685

# %% [markdown]
# ## saving the decision tree model for future prediction

# %%
import pickle
filename = open('final_model.pkl','wb')
pickle.dump(model,filename)
filename.close()

# %%
loaded_model = pickle.load(open('final_model.pkl','rb'))
result = loaded_model.score(X_test,y_test)
print(result)
# Out:
# 0.9418994413407821
